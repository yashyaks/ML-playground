# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import seaborn as sns

# %% [markdown]
# ## Importing data into dataframes with pandas

# %%
matches_df = pd.read_csv('matches.csv')

# %%
matches_df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
matches_df
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
# ...

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Columns: 115 entries, id to BSA
# dtypes: float64(96), int64(9), object(10)
# memory usage: 22.8+ MB

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#     Unnamed: 0     id         name
# 0            0      1      Belgium
# 1            1   1729      England
# 2            2   4769       France
# 3            3   7809      Germany
# 4            4  10257        Italy
# 5            5  13274  Netherlands
# 6            6  15722       Poland
# 7            7  17642     Portugal
# 8            8  19694     Scotland
# 9            9  21518        Spain
# 10          10  24558  Switzerland

# %% [markdown]
# ### Renaming column 'name' to 'country_name' & dropping unnamed column

# %%
countries_df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
countries_df.rename(columns={'id': 'country_id','name': 'country_name'}, inplace=True)

# %%
countries_df
# Out:
#     country_id country_name
# 0            1      Belgium
# 1         1729      England
# 2         4769       France
# 3         7809      Germany
# 4        10257        Italy
# 5        13274  Netherlands
# 6        15722       Poland
# 7        17642     Portugal
# 8        19694     Scotland
# 9        21518        Spain
# 10       24558  Switzerland

# %%
leagues_df = pd.read_csv('leagues.csv')

# %%
leagues_df
# Out:
#     Unnamed: 0     id  country_id                      name   id.1  \
# 0            0      1           1    Belgium Jupiler League      1
# 1            1   1729        1729    England Premier League   1729
# 2            2   4769        4769            France Ligue 1   4769
# 3            3   7809        7809     Germany 1. Bundesliga   7809
# 4            4  10257       10257             Italy Serie A  10257
# 5            5  13274       13274    Netherlands Eredivisie  13274
# 6            6  15722       15722        Poland Ekstraklasa  15722
# 7            7  17642       17642  Portugal Liga ZON Sagres  17642
# 8            8  19694       19694   Scotland Premier League  19694
# 9            9  21518       21518           Spain LIGA BBVA  21518
# 10          10  24558       24558  Switzerland Super League  24558
#
#          name.1
# 0       Belgium
# 1       England
# 2        France
# 3       Germany
# 4         Italy
# 5   Netherlands
# 6        Poland
# 7      Portugal
# ...

# %% [markdown]
# ### Renaming columns & dropping unnamed column

# %%
leagues_df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
leagues_df.rename(columns={'name': 'league_name','name.1': 'country_name','id.1': 'league_id'}, inplace=True)

# %%
leagues_df
# Out:
#        id  country_id               league_name  league_id country_name
# 0       1           1    Belgium Jupiler League          1      Belgium
# 1    1729        1729    England Premier League       1729      England
# 2    4769        4769            France Ligue 1       4769       France
# 3    7809        7809     Germany 1. Bundesliga       7809      Germany
# 4   10257       10257             Italy Serie A      10257        Italy
# 5   13274       13274    Netherlands Eredivisie      13274  Netherlands
# 6   15722       15722        Poland Ekstraklasa      15722       Poland
# 7   17642       17642  Portugal Liga ZON Sagres      17642     Portugal
# 8   19694       19694   Scotland Premier League      19694     Scotland
# 9   21518       21518           Spain LIGA BBVA      21518        Spain
# 10  24558       24558  Switzerland Super League      24558  Switzerland

# %%
df = pd.merge(matches_df, leagues_df, on='id', how='left').drop_duplicates()

# %%
df
# Out:
#           id  country_id_x  league_id_x     season  stage  \
# 0          1             1            1  2008/2009      1
# 1          2             1            1  2008/2009      1
# 2          3             1            1  2008/2009      1
# 3          4             1            1  2008/2009      1
# 4          5             1            1  2008/2009      1
# ...      ...           ...          ...        ...    ...
# 25974  25975         24558        24558  2015/2016      9
# 25975  25976         24558        24558  2015/2016      9
# 25976  25977         24558        24558  2015/2016      9
# 25977  25978         24558        24558  2015/2016      9
# 25978  25979         24558        24558  2015/2016      9
#
#                       date  match_api_id  home_team_api_id  away_team_api_id  \
# 0      2008-08-17 00:00:00        492473              9987              9993
# 1      2008-08-16 00:00:00        492474             10000              9994
# ...

# %%
df.dropna(axis=1)
# Out:
#           id  country_id_x  league_id_x     season  stage  \
# 0          1             1            1  2008/2009      1
# 1          2             1            1  2008/2009      1
# 2          3             1            1  2008/2009      1
# 3          4             1            1  2008/2009      1
# 4          5             1            1  2008/2009      1
# ...      ...           ...          ...        ...    ...
# 25974  25975         24558        24558  2015/2016      9
# 25975  25976         24558        24558  2015/2016      9
# 25976  25977         24558        24558  2015/2016      9
# 25977  25978         24558        24558  2015/2016      9
# 25978  25979         24558        24558  2015/2016      9
#
#                       date  match_api_id  home_team_api_id  away_team_api_id  \
# 0      2008-08-17 00:00:00        492473              9987              9993
# 1      2008-08-16 00:00:00        492474             10000              9994
# ...
