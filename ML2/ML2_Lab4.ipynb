# %% [markdown]
# <a href="https://colab.research.google.com/github/yashyaks/ML-Playground/blob/main/ML2/ML2_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
plt.matshow(x_train[0])
plt.matshow(x_train[1])
plt.matshow(x_train[2])
plt.matshow(x_train[3])
plt.matshow(x_train[4])
print ("In order of apperance, the first 5 elements are : " + str(y_train[0]) + ", " + str(y_train[1]) + ", " +
       str(y_train[2]) + ", " + str(y_train[3]) + ", " + str(y_train[4]))
# Out:
# In order of apperance, the first 5 elements are : 5, 0, 4, 1, 9

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dropout (Dropout)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.2982 - accuracy: 0.9129
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1540 - accuracy: 0.9546
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1200 - accuracy: 0.9640
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1006 - accuracy: 0.9699
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0922 - accuracy: 0.9729
# Epoch 6/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0844 - accuracy: 0.9760
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0786 - accuracy: 0.9771
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0695 - accuracy: 0.9791
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0670 - accuracy: 0.9799
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0654 - accuracy: 0.9810
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0788 - accuracy: 0.9799
# [0.07880294322967529, 0.9799000024795532]

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.compile(optimizer="adam",loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history1=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0676 - accuracy: 0.9796
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0618 - accuracy: 0.9805
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0521 - accuracy: 0.9833
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0490 - accuracy: 0.9838
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0475 - accuracy: 0.9847
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0445 - accuracy: 0.9853
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0435 - accuracy: 0.9855
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0386 - accuracy: 0.9872
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0377 - accuracy: 0.9873
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0364 - accuracy: 0.9876
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0707 - accuracy: 0.9802
# [0.0707167461514473, 0.9801999926567078]

# %%
predictions = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
plt.plot(history1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history1.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.compile(optimizer="sgd",loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history2=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0256 - accuracy: 0.9908
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0218 - accuracy: 0.9922
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0206 - accuracy: 0.9928
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0201 - accuracy: 0.9932
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0208 - accuracy: 0.9931
# Epoch 6/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0200 - accuracy: 0.9932
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0194 - accuracy: 0.9937
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0193 - accuracy: 0.9934
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0188 - accuracy: 0.9937
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0185 - accuracy: 0.9939

# %%
predictions = model.predict(x_test)

# %%
plt.plot(history2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history2.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from keras.optimizers import SGD
optimizer=SGD(momentum=0.1)
model.compile(optimizer=optimizer,loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history5=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)

# %%
plt.plot(history5.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history5.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.compile(optimizer="Adagrad",loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history3=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)

# %%
plt.plot(history3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history3.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model.compile(optimizer="AdaDelta",loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history4=model.fit(x_train, y_train, epochs=10)
model.evaluate(x_test, y_test)

# %%
plt.plot(history4.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history4.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
